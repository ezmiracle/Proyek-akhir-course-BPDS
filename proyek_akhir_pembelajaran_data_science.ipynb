# %% [markdown]
# # Proyek Akhir: Menyelesaikan Permasalahan Perusahaan Edutech
#
# - Nama: Diaz Darsya Rizqullah
# - Email: diazdarsya@gmail.com
# - Id Dicoding: diazdarsya

# %% [markdown]
# ## Persiapan

# %% [markdown]
# ### Menyiapkan library yang dibutuhkan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Menyiapkan data yang akan digunakan
# ##Data Understanding

# %%
institusi_diaz_df = pd.read_csv(
    "https://raw.githubusercontent.com/dicodingacademy/dicoding_dataset/main/students_performance/data.csv",
    encoding='utf-8',
    delimiter=";",
)

institusi_diaz_df.head(5)
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %%
institusi_diaz_df.isna().sum()
# Out:
# Marital_status                                  0
# Application_mode                                0
# Application_order                               0
# Course                                          0
# Daytime_evening_attendance                      0
# Previous_qualification                          0
# Previous_qualification_grade                    0
# Nacionality                                     0
# Mothers_qualification                           0
# Fathers_qualification                           0
# Mothers_occupation                              0
# Fathers_occupation                              0
# Admission_grade                                 0
# Displaced                                       0
# Educational_special_needs                       0
# Debtor                                          0
# Tuition_fees_up_to_date                         0
# Gender                                          0
# Scholarship_holder                              0
# ...

# %%
institusi_diaz_df.isnull().sum()
# Out:
# Marital_status                                  0
# Application_mode                                0
# Application_order                               0
# Course                                          0
# Daytime_evening_attendance                      0
# Previous_qualification                          0
# Previous_qualification_grade                    0
# Nacionality                                     0
# Mothers_qualification                           0
# Fathers_qualification                           0
# Mothers_occupation                              0
# Fathers_occupation                              0
# Admission_grade                                 0
# Displaced                                       0
# Educational_special_needs                       0
# Debtor                                          0
# Tuition_fees_up_to_date                         0
# Gender                                          0
# Scholarship_holder                              0
# ...

# %%
#Make sure datas type
institusi_diaz_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Marital_status                                4424 non-null   int64
#  1   Application_mode                              4424 non-null   int64
#  2   Application_order                             4424 non-null   int64
#  3   Course                                        4424 non-null   int64
#  4   Daytime_evening_attendance                    4424 non-null   int64
#  5   Previous_qualification                        4424 non-null   int64
#  6   Previous_qualification_grade                  4424 non-null   float64
#  7   Nacionality                                   4424 non-null   int64
#  8   Mothers_qualification                         4424 non-null   int64
# ...

# %%
institusi_diaz_df.describe(include="all")
# Out:
#         Marital_status  Application_mode  Application_order       Course  \
# count      4424.000000       4424.000000        4424.000000  4424.000000
# unique             NaN               NaN                NaN          NaN
# top                NaN               NaN                NaN          NaN
# freq               NaN               NaN                NaN          NaN
# mean          1.178571         18.669078           1.727848  8856.642631
# std           0.605747         17.484682           1.313793  2063.566416
# min           1.000000          1.000000           0.000000    33.000000
# 25%           1.000000          1.000000           1.000000  9085.000000
# 50%           1.000000         17.000000           1.000000  9238.000000
# 75%           1.000000         39.000000           2.000000  9556.000000
# max           6.000000         57.000000           9.000000  9991.000000
#
#         Daytime_evening_attendance  Previous_qualification  \
# ...

# %%
categorical_columns = [
    "Marital_status",
    "Application_mode",
    "Course",
    "Daytime_evening_attendance",
    "Previous_qualification",
    "Nacionality",
    "International",
    "Mothers_qualification",
    "Fathers_qualification",
    "Mothers_occupation",
    "Fathers_occupation",
    "Displaced",
    "Educational_special_needs",
    "Debtor",
    "Tuition_fees_up_to_date",
    "Gender",
    "Scholarship_holder",
    "International",
]


fig, ax = plt.subplots(len(categorical_columns), 1,figsize=(20,100))
for i, feature in enumerate(categorical_columns):
    sns.countplot(data=institusi_diaz_df, y=feature, hue=feature, ax=ax[i])
plt.tight_layout()
plt.show()

# %%
for column in categorical_columns:
  print(institusi_diaz_df[column].value_counts(),"\n")
# Out:
# Marital_status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64
#
# Application_mode
# 1     1708
# 17     872
# 39     785
# 43     312
# 44     213
# 7      139
# 18     124
# 42      77
# 51      59
# 16      38
# 53      35
# 15      30
# 5       16
# 10      10
# 2        3
# 57       1
# 26       1
# 27       1
# Name: count, dtype: int64
#
# Course
# 9500    766
# 9147    380
# 9238    355
# 9085    337
# 9773    331
# 9670    268
# 9991    268
# 9254    252
# 9070    226
# 171     215
# 8014    215
# 9003    210
# 9853    192
# 9119    170
# 9130    141
# 9556     86
# 33       12
# Name: count, dtype: int64
#
# Daytime_evening_attendance
# 1    3941
# 0     483
# Name: count, dtype: int64
#
# Previous_qualification
# 1     3717
# 39     219
# 19     162
# 3      126
# 12      45
# 40      40
# 42      36
# 2       23
# 6       16
# 9       11
# 4        8
# 38       7
# 43       6
# 10       4
# 15       2
# 5        1
# ...

# %%
numerical_columns = [
  "Admission_grade",
  "Application_order",
  "Age_at_enrollment",
  "Curricular_units_1st_sem_enrolled",
  "Curricular_units_1st_sem_evaluations",
  "Curricular_units_1st_sem_approved",
  "Curricular_units_1st_sem_grade",
  "Curricular_units_2nd_sem_enrolled",
  "Curricular_units_2nd_sem_evaluations",
  "Curricular_units_2nd_sem_approved",
  "Curricular_units_2nd_sem_grade",
  "Unemployment_rate",
  "Inflation_rate",
  "GDP",
  "Previous_qualification_grade"
]

# %%
def numerical_dis_plot(features, diaz_df, segment_feature=None, showfliers=True):
    fig, ax = plt.subplots(len(features), 1,figsize=(15,30))
    for i, feature in enumerate(features):
        if segment_feature:
            sns.boxplot(y=segment_feature, x=feature, data=diaz_df, ax=ax[i], showfliers=showfliers)
            ax[i].set_ylabel(None)
        else:
            sns.boxplot(x=feature, data=diaz_df, ax=ax[i], showfliers=showfliers)
    plt.tight_layout()
    plt.show()

numerical_dis_plot(
    features=numerical_columns,
    diaz_df=institusi_diaz_df
)

# %%
numerical_dis_plot(
    features=numerical_columns,
    diaz_df=institusi_diaz_df,
    segment_feature="Status"
)

# %%
def categorical_plot(features, diaz_df, segment_feature=None):
    fig, ax = plt.subplots(len(features), 1,figsize=(20,100))
    for i, feature in enumerate(features):
        if segment_feature:
            sns.countplot(data=diaz_df, y=segment_feature, hue=feature, ax=ax[i])
        else:
            sns.countplot(data=diaz_df, x=feature, ax=ax[i])
    plt.tight_layout()
    plt.show()

# %%
categorical_plot(
    features=categorical_columns,
    diaz_df=institusi_diaz_df,
    segment_feature="Status"
)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(institusi_diaz_df[numerical_columns].corr(), annot=True, cmap='jet', linecolor='black', linewidth=1)
plt.show()

# %% [markdown]
# ## Data Preparation / Preprocessing

# %% [markdown]
# ### Train-test Split

# %%
new_cleaned_diaz_df = institusi_diaz_df.drop(columns=["Curricular_units_1st_sem_credited", "Curricular_units_1st_sem_without_evaluations", "Curricular_units_2nd_sem_credited", "Curricular_units_2nd_sem_without_evaluations"],axis=1)
new_cleaned_diaz_df.head(5)
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                17                  5     171
# 1               1                15                  1    9254
# 2               1                 1                  5    9070
# 3               1                17                  2    9773
# 4               2                39                  1    8014
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           0                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                         122.0            1                     19
# 1                         160.0            1                      1
# ...

# %%
from sklearn.model_selection import train_test_split

train_diaz_df, test_diaz_df = train_test_split(new_cleaned_diaz_df, test_size=0.05, random_state=42, shuffle=True)
train_diaz_df.reset_index(drop=True, inplace=True)
test_diaz_df.reset_index(drop=True, inplace=True)

print(train_diaz_df.shape)
print(test_diaz_df.shape)
# Out:
# (4202, 33)
# (222, 33)

# %% [markdown]
# ### Oversampling

# %%
sns.countplot(data=train_diaz_df, x="Status", hue="Status")
plt.show()

# %%
train_diaz_df.Status.value_counts()
# Out:
# Status
# Graduate    2101
# Dropout     1349
# Enrolled     752
# Name: count, dtype: int64

# %%
diaz_df_majority_1 = train_diaz_df[(train_diaz_df.Status == "Graduate")]
diaz_df_majority_2 = train_diaz_df[(train_diaz_df.Status == "Dropout")]
diaz_df_minority = train_diaz_df[(train_diaz_df.Status == "Enrolled")]

# %%
from sklearn.utils import resample

diaz_df_majority_2_undersampled = resample(diaz_df_majority_2, n_samples=2101, random_state=42) # Oversampling
diaz_df_minority_undersampled  = resample(diaz_df_minority, n_samples=2101, random_state=42)
print(diaz_df_majority_2_undersampled.shape)
print(diaz_df_minority_undersampled.shape)
# Out:
# (2101, 33)
# (2101, 33)

# %%
from sklearn.utils import shuffle

oversampled_train_diaz_df  = pd.concat([diaz_df_majority_1, diaz_df_majority_2_undersampled]).reset_index(drop=True)
oversampled_train_diaz_df = pd.concat([oversampled_train_diaz_df, diaz_df_minority_undersampled]).reset_index(drop=True)
oversampled_train_diaz_df = shuffle(oversampled_train_diaz_df, random_state=42)
oversampled_train_diaz_df.reset_index(drop=True, inplace=True)
oversampled_train_diaz_df.sample(5)
# Out:
#       Marital_status  Application_mode  Application_order  Course  \
# 3476               1                10                  1    9500
# 5525               1                39                  1    9003
# 5023               1                43                  1    9670
# 3235               1                39                  1    8014
# 2735               1                43                  1    9853
#
#       Daytime_evening_attendance  Previous_qualification  \
# 3476                           1                       1
# 5525                           1                       1
# 5023                           1                       1
# 3235                           0                       1
# 2735                           1                       1
#
#       Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 3476                         140.0           24                      3
# 5525                         140.0            1                     37
# ...

# %%
oversampled_train_diaz_df.Status.value_counts()
# Out:
# Status
# Graduate    2101
# Enrolled    2101
# Dropout     2101
# Name: count, dtype: int64

# %%
oversampled_train_diaz_df.shape
# Out:
# (6303, 33)

# %%
sns.countplot(data=oversampled_train_diaz_df,x="Status",hue="Status")
plt.show()

# %% [markdown]
# ### Split X and Y

# %%
X_train = oversampled_train_diaz_df.drop(columns="Status", axis=1)
y_train = oversampled_train_diaz_df["Status"]

X_test = test_diaz_df.drop(columns="Status", axis=1)
y_test = test_diaz_df["Status"]

# %% [markdown]
# ### Standarizing & Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import joblib

def scaling(features, diaz_df, diaz_df_test=None):
    if diaz_df_test is not None:
        diaz_df = diaz_df.copy()
        diaz_df_test = diaz_df_test.copy()
        diaz_df = diaz_df.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(diaz_df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            diaz_df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "/content/drive/MyDrive/model/scaler_{}.joblib".format(feature))

            X_test = np.asanyarray(diaz_df_test[feature])
            X_test = X_test.reshape(-1,1)
            diaz_df_test["{}".format(feature)] = scaler.transform(X_test)
        return diaz_df, diaz_df_test
    else:
        diaz_df = diaz_df.copy()
        for feature in features:
            scaler = MinMaxScaler()
            X = np.asanyarray(diaz_df[feature])
            X = X.reshape(-1,1)
            scaler.fit(X)
            diaz_df["{}".format(feature)] = scaler.transform(X)
            joblib.dump(scaler, "/content/drive/MyDrive/model/scaler_{}.joblib".format(feature))
        return diaz_df


def encoding(features, diaz_df, diaz_df_test=None):
    diaz_df_train = diaz_df.copy()

    for feature in features:
        encoder = LabelEncoder()
        encoder.fit(diaz_df_train[feature])
        diaz_df_train[feature] = encoder.transform(diaz_df_train[feature])
        joblib.dump(encoder, "/content/drive/MyDrive/model/encoder_{}.joblib".format(feature))

        if diaz_df_test is not None:
            # Handle unseen labels in test data
            diaz_df_test[feature] = diaz_df_test[feature].apply(lambda x: x if x in encoder.classes_ else encoder.classes_[0])

    if diaz_df_test is not None:
        return diaz_df_train, diaz_df_test
    else:
        return diaz_df_train

# %%
new_train_diaz_df, new_test_diaz_df = scaling(numerical_columns, X_train, X_test)
new_train_diaz_df, new_test_diaz_df = encoding(categorical_columns, new_train_diaz_df, new_test_diaz_df)

# %%
new_train_diaz_df
# Out:
#       Marital_status  Application_mode  Application_order  Course  \
# 0                  1                11           0.166667       7
# 1                  0                 8           0.166667       2
# 2                  0                 0           0.166667      13
# 3                  0                 0           0.166667       8
# 4                  0                 7           0.333333       2
# ...              ...               ...                ...     ...
# 6298               0                 0           0.500000      14
# 6299               0                 7           0.333333       6
# 6300               0                 0           0.500000      11
# 6301               0                 7           0.166667       9
# 6302               0                 7           0.166667       7
#
#       Daytime_evening_attendance  Previous_qualification  \
# 0                              1                      10
# ...

# %%
encoder = LabelEncoder()
encoder.fit(y_train)
new_y_train = encoder.transform(y_train)
joblib.dump(encoder, "/content/drive/MyDrive/model/encoder_target.joblib")

new_y_test = encoder.transform(y_test)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(new_train_diaz_df[numerical_columns].corr(), annot=True, cmap='jet', linecolor='black', linewidth=1)
plt.show()

# %%
new_y_train
# Out:
# array([2, 2, 2, ..., 1, 1, 2])

# %% [markdown]
# ### PCA

# %%
len(numerical_columns)
# Out:
# 15

# %%
pca_numerical_columns_1 = [
  "Curricular_units_1st_sem_enrolled",
  "Curricular_units_1st_sem_evaluations",
  "Curricular_units_1st_sem_approved",
  "Curricular_units_1st_sem_grade",
  "Curricular_units_2nd_sem_enrolled",
  "Curricular_units_2nd_sem_evaluations",
  "Curricular_units_2nd_sem_approved",
  "Curricular_units_2nd_sem_grade",
]

pca_numerical_columns_2 = [
  "Admission_grade",
  "GDP",
  "Age_at_enrollment",
  "Previous_qualification_grade"
]

# %%
train_pca_diaz_df = new_train_diaz_df.copy().reset_index(drop=True)
test_pca_diaz_df = new_test_diaz_df.copy().reset_index(drop=True)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=len(pca_numerical_columns_1), random_state=123)
pca.fit(train_pca_diaz_df[pca_numerical_columns_1])
princ_comp = pca.transform(train_pca_diaz_df[pca_numerical_columns_1])

var_exp = pca.explained_variance_ratio_.round(3)
cum_var_exp = np.cumsum(var_exp)

plt.bar(range(len(pca_numerical_columns_1)), var_exp, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(len(pca_numerical_columns_1)), cum_var_exp, where='mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.show()

# %%
cum_var_exp
# Out:
# array([0.751, 0.854, 0.921, 0.968, 0.982, 0.993, 1.   , 1.001])

# %%
pca_1 = PCA(n_components=2, random_state=123)
pca_1.fit(train_pca_diaz_df[pca_numerical_columns_1])
joblib.dump(pca_1, "/content/drive/MyDrive/model/pca_{}.joblib".format(1))
princ_comp_1 = pca_1.transform(train_pca_diaz_df[pca_numerical_columns_1])
train_pca_diaz_df[["pc1_1", "pc1_2"]] = pd.DataFrame(princ_comp_1, columns=["pc1_1", "pc1_2"])
train_pca_diaz_df.drop(columns=pca_numerical_columns_1, axis=1, inplace=True)
train_pca_diaz_df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                11           0.166667       7
# 1               0                 8           0.166667       2
# 2               0                 0           0.166667      13
# 3               0                 0           0.166667       8
# 4               0                 7           0.333333       2
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                      10
# 1                           0                       0
# 2                           1                       0
# 3                           1                       0
# 4                           0                       0
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                      0.394681            0                     20
# 1                      0.436170            0                      0
# ...

# %%
pca = PCA(n_components=len(pca_numerical_columns_2), random_state=123)
pca.fit(train_pca_diaz_df[pca_numerical_columns_2])
princ_comp = pca.transform(train_pca_diaz_df[pca_numerical_columns_2])

var_exp = pca.explained_variance_ratio_.round(3)
cum_var_exp = np.cumsum(var_exp)

plt.bar(range(len(pca_numerical_columns_2)), var_exp, alpha=0.5, align='center', label='individual explained variance')
plt.step(range(len(pca_numerical_columns_2)), cum_var_exp, where='mid', label='cumulative explained variance')
plt.ylabel('Explained variance ratio')
plt.xlabel('Principal component index')
plt.legend(loc='best')
plt.show()

# %%
cum_var_exp
# Out:
# array([0.564, 0.778, 0.945, 0.999])

# %%
pca_2 = PCA(n_components=2, random_state=123)
pca_2.fit(train_pca_diaz_df[pca_numerical_columns_2])
joblib.dump(pca_2, "/content/drive/MyDrive/model/pca_{}.joblib".format(2))
princ_comp_2 = pca_2.transform(train_pca_diaz_df[pca_numerical_columns_2])
train_pca_diaz_df[["pc2_1", "pc2_2"]] = pd.DataFrame(princ_comp_2, columns=["pc2_1", "pc2_2"])
train_pca_diaz_df.drop(columns=pca_numerical_columns_2, axis=1, inplace=True)
train_pca_diaz_df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               1                11           0.166667       7
# 1               0                 8           0.166667       2
# 2               0                 0           0.166667      13
# 3               0                 0           0.166667       8
# 4               0                 7           0.333333       2
#
#    Daytime_evening_attendance  Previous_qualification  Nacionality  \
# 0                           1                      10            0
# 1                           0                       0            0
# 2                           1                       0            0
# 3                           1                       0            0
# 4                           0                       0            0
#
#    Mothers_qualification  Fathers_qualification  Mothers_occupation  ...  \
# 0                     20                     25                   9  ...
# ...

# %%
test_princ_comp_1 = pca_1.transform(test_pca_diaz_df[pca_numerical_columns_1])
test_pca_diaz_df[["pc1_1", "pc1_2"]] = pd.DataFrame(test_princ_comp_1, columns=["pc1_1", "pc1_2"])
test_pca_diaz_df.drop(columns=pca_numerical_columns_1, axis=1, inplace=True)
test_pca_diaz_df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               4                39           0.166667    9130
# 1               1                17           0.166667    9238
# 2               1                17           0.166667    9853
# 3               1                17           0.333333    9670
# 4               1                39           0.166667    9500
#
#    Daytime_evening_attendance  Previous_qualification  \
# 0                           1                       1
# 1                           1                       1
# 2                           1                       1
# 3                           1                       1
# 4                           1                       1
#
#    Previous_qualification_grade  Nacionality  Mothers_qualification  \
# 0                      0.394681            1                      3
# 1                      0.308511            1                      4
# ...

# %%
test_princ_comp_1 = pca_2.transform(test_pca_diaz_df[pca_numerical_columns_2])
test_pca_diaz_df[["pc2_1", "pc2_2"]] = pd.DataFrame(test_princ_comp_1, columns=["pc2_1", "pc2_2"])
test_pca_diaz_df.drop(columns=pca_numerical_columns_2, axis=1, inplace=True)
test_pca_diaz_df.head()
# Out:
#    Marital_status  Application_mode  Application_order  Course  \
# 0               4                39           0.166667    9130
# 1               1                17           0.166667    9238
# 2               1                17           0.166667    9853
# 3               1                17           0.333333    9670
# 4               1                39           0.166667    9500
#
#    Daytime_evening_attendance  Previous_qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           1                       1            1
#
#    Mothers_qualification  Fathers_qualification  Mothers_occupation  ...  \
# 0                      3                      1                   5  ...
# ...

# %%
len(train_pca_diaz_df.columns)
# Out:
# 24

# %% [markdown]
# #Modelling

# %% [markdown]
# ##Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

log_model = LogisticRegression(random_state=123, max_iter=4000)

param_grid = {
    "penalty": ["l1","l2", "elasticnet"],
    "C": [0.01, 0.1, 1]
}

CV_log = GridSearchCV(estimator=log_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_log.fit(train_pca_diaz_df, new_y_train)
print("best parameters: ", CV_log.best_params_)
print("accuracy : ", CV_log.best_score_)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 30 fits failed out of a total of 45.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1389, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
log_model = LogisticRegression(random_state=123, C=1, penalty='l2', max_iter=4000)
log_model.fit(train_pca_diaz_df, new_y_train)
joblib.dump(log_model, "/content/drive/MyDrive/model/log_model.joblib")
# Out:
# ['/content/drive/MyDrive/model/log_model.joblib']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

def evaluating(y_pred, y_true):
    labels=['Enrolled','Graduate','Dropout']

    # acc = round(accuracy_score(y_pred=y_pred, y_true=y_true), 2)
    # recall = round(recall_score(y_pred=y_pred, y_true=y_true, average="micro"), 2)
    # precission = round(precision_score(y_pred=y_pred, y_true=y_true, average="micro"), 2)
    # f1 = round(f1_score(y_pred=y_pred, y_true=y_true, average="micro"), 2)
    cnf_matrix = confusion_matrix(y_pred=y_pred, y_true=y_true, labels=labels)
    confusion_matrix_diaz_df = pd.DataFrame(cnf_matrix, labels, labels)

    return confusion_matrix_diaz_df #acc, recall, precission, f1

# %%
y_pred_train = log_model.predict(train_pca_diaz_df)
y_pred_train = encoder.inverse_transform(y_pred_train)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_train, y_true=y_train)
print(classification_report(y_pred=y_pred_train, y_true=y_train))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.74      0.70      0.72      2101
#     Enrolled       0.54      0.50      0.52      2101
#     Graduate       0.63      0.71      0.66      2101
#
#     accuracy                           0.64      6303
#    macro avg       0.64      0.64      0.63      6303
# weighted avg       0.64      0.64      0.63      6303

# %%
y_pred_test = log_model.predict(test_pca_diaz_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_test, y_true=y_test)
# print("accuracy: ", acc)
# print("recall: ", recall)
# print("precission: ", precission)
# print("F1 Score: ", f1)
print(classification_report(y_pred=y_pred_test, y_true=y_test))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.32      1.00      0.49        72
#     Enrolled       0.00      0.00      0.00        42
#     Graduate       0.00      0.00      0.00       108
#
#     accuracy                           0.32       222
#    macro avg       0.11      0.33      0.16       222
# weighted avg       0.11      0.32      0.16       222
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
def plot_feature_importances(feature_importances, cols):
    features = pd.DataFrame(feature_importances, columns=['coef_value']).set_index(cols)
    features = features.sort_values(by='coef_value', ascending=False)
    top_features = features
    # features = features.head(20)
    plt.figure(figsize=(10, 6))
    sns.barplot(x='coef_value', y=features.index, data=features)
    plt.show()
    return top_features

plot_feature_importances(np.mean(np.abs(log_model.coef_), axis=0), train_pca_diaz_df.columns)
# Out:
#                             coef_value
# pc1_1                         1.818092
# Tuition_fees_up_to_date       1.109004
# pc1_2                         1.048950
# pc2_2                         0.612433
# International                 0.552134
# Scholarship_holder            0.497692
# Debtor                        0.384711
# Educational_special_needs     0.254358
# Gender                        0.235654
# Unemployment_rate             0.226681
# Application_order             0.205446
# pc2_1                         0.114344
# Daytime_evening_attendance    0.101633
# Marital_status                0.080423
# Inflation_rate                0.075243
# Nacionality                   0.058677
# Course                        0.046812
# Displaced                     0.040029
# Application_mode              0.023443
# Fathers_occupation            0.017458
# Previous_qualification        0.016035
# Mothers_occupation            0.014185
# Mothers_qualification         0.011813
# ...

# %% [markdown]
# ##Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model = DecisionTreeClassifier(random_state=123)

# %%
param_grid = {
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [5, 6, 7, 8],
    'criterion' :['gini', 'entropy']
}

CV_tree = GridSearchCV(estimator=tree_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_tree.fit(train_pca_diaz_df, new_y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
print("best parameters: ", CV_tree.best_params_)
print("accuracy : ", CV_tree.best_score_)
# Out:
# best parameters:  {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt'}
# accuracy :  0.651908538197198

# %%
tree_model = DecisionTreeClassifier(
    random_state=123,
    criterion='entropy',
    max_depth=7,
    max_features='sqrt'
)

tree_model.fit(train_pca_diaz_df, new_y_train)
joblib.dump(tree_model, "/content/drive/MyDrive/model/tree_model.joblib")
# Out:
# ['/content/drive/MyDrive/model/tree_model.joblib']

# %%
y_pred_train = tree_model.predict(train_pca_diaz_df)
y_pred_train = encoder.inverse_transform(y_pred_train)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_train, y_true=y_train)
# print("accuracy: ", acc)
# print("recall: ", recall)
# print("precissiony: ", precission)
# print("F1 Score: ", f1)
print(classification_report(y_pred=y_pred_train, y_true=y_train))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.84      0.69      0.76      2101
#     Enrolled       0.59      0.40      0.48      2101
#     Graduate       0.56      0.84      0.67      2101
#
#     accuracy                           0.64      6303
#    macro avg       0.66      0.64      0.63      6303
# weighted avg       0.66      0.64      0.63      6303

# %%
y_pred_test = tree_model.predict(test_pca_diaz_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_test, y_true=y_test)
# print("accuracy: ", acc)
# print("recall: ", recall)
# print("precissiony: ", precission)
# print("F1 Score: ", f1)
print(classification_report(y_pred=y_pred_test, y_true=y_test))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.69      0.65      0.67        72
#     Enrolled       0.28      0.38      0.32        42
#     Graduate       0.71      0.64      0.67       108
#
#     accuracy                           0.59       222
#    macro avg       0.56      0.56      0.56       222
# weighted avg       0.62      0.59      0.61       222

# %%
plot_feature_importances(tree_model.feature_importances_, train_pca_diaz_df.columns)
# Out:
#                             coef_value
# pc1_1                         0.506236
# pc1_2                         0.104165
# Tuition_fees_up_to_date       0.087083
# Scholarship_holder            0.057948
# pc2_2                         0.032924
# Application_mode              0.027134
# Course                        0.025305
# Inflation_rate                0.023715
# Fathers_occupation            0.019910
# Mothers_occupation            0.019405
# Unemployment_rate             0.018007
# pc2_1                         0.017995
# Mothers_qualification         0.017771
# Previous_qualification        0.015578
# Application_order             0.010063
# Gender                        0.006171
# International                 0.003894
# Fathers_qualification         0.003176
# Nacionality                   0.002712
# Debtor                        0.000808
# Daytime_evening_attendance    0.000000
# Marital_status                0.000000
# Educational_special_needs     0.000000
# ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rdiaz_df_model = RandomForestClassifier(random_state=123)

# %%
param_grid = {
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [6, 7, 8],
    'criterion' :['gini', 'entropy']
}

CV_rdiaz_df = GridSearchCV(estimator=rdiaz_df_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_rdiaz_df.fit(train_pca_diaz_df, new_y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 60 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
print("best parameters: ", CV_rdiaz_df.best_params_)
print("accuracy : ", CV_rdiaz_df.best_score_)
# Out:
# best parameters:  {'criterion': 'gini', 'max_depth': 8, 'max_features': 'sqrt', 'n_estimators': 500}
# accuracy :  0.7690015482798988

# %%
rdf_model = RandomForestClassifier(
    random_state=123,
    max_depth=8,
    n_estimators=500,
    max_features='sqrt',
    criterion='gini',
    n_jobs=-1
)
rdiaz_df_model.fit(train_pca_diaz_df, new_y_train)
joblib.dump(rdiaz_df_model, "/content/drive/MyDrive/model/rdf_model.joblib")
# Out:
# ['/content/drive/MyDrive/model/rdf_model.joblib']

# %%
y_pred_train = rdiaz_df_model.predict(train_pca_diaz_df)
y_pred_train = encoder.inverse_transform(y_pred_train)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_train, y_true=y_train)
print(classification_report(y_pred=y_pred_train, y_true=y_train))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       1.00      1.00      1.00      2101
#     Enrolled       1.00      1.00      1.00      2101
#     Graduate       1.00      1.00      1.00      2101
#
#     accuracy                           1.00      6303
#    macro avg       1.00      1.00      1.00      6303
# weighted avg       1.00      1.00      1.00      6303

# %%
y_pred_test = rdiaz_df_model.predict(test_pca_diaz_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_test, y_true=y_test)
print(classification_report(y_pred=y_pred_test, y_true=y_test))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.70      0.78      0.74        72
#     Enrolled       0.37      0.24      0.29        42
#     Graduate       0.74      0.79      0.76       108
#
#     accuracy                           0.68       222
#    macro avg       0.60      0.60      0.60       222
# weighted avg       0.66      0.68      0.66       222

# %%
rdiaz_df_model.feature_importances_
# Out:
# array([0.00805579, 0.03802155, 0.02198674, 0.05678322, 0.00531312,
#        0.01360269, 0.00357041, 0.03750163, 0.03540738, 0.0458385 ,
#        0.05106455, 0.01405393, 0.00135009, 0.01497029, 0.04219412,
#        0.01595406, 0.02537145, 0.00312325, 0.0363311 , 0.0344305 ,
#        0.23209808, 0.10166414, 0.07823939, 0.08307404])

# %%
plot_feature_importances(rdiaz_df_model.feature_importances_, train_pca_diaz_df.columns)
# Out:
#                             coef_value
# pc1_1                         0.232098
# pc1_2                         0.101664
# pc2_2                         0.083074
# pc2_1                         0.078239
# Course                        0.056783
# Fathers_occupation            0.051065
# Mothers_occupation            0.045838
# Tuition_fees_up_to_date       0.042194
# Application_mode              0.038022
# Mothers_qualification         0.037502
# Unemployment_rate             0.036331
# Fathers_qualification         0.035407
# Inflation_rate                0.034431
# Scholarship_holder            0.025371
# Application_order             0.021987
# Gender                        0.015954
# Debtor                        0.014970
# Displaced                     0.014054
# Previous_qualification        0.013603
# Marital_status                0.008056
# Daytime_evening_attendance    0.005313
# Nacionality                   0.003570
# International                 0.003123
# ...

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gboost_model = GradientBoostingClassifier(random_state=123)

param_grid = {
    'max_depth': [5, 8],
    'n_estimators': [200, 300],
    'learning_rate': [0.01, 0.1],
    'max_features': ['auto', 'sqrt', 'log2']
}

CV_gboost = GridSearchCV(estimator=gboost_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_gboost.fit(train_pca_diaz_df, new_y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 40 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
print("best parameters: ", CV_gboost.best_params_)
print("accuracy : ", CV_gboost.best_score_)
# Out:
# best parameters:  {'learning_rate': 0.1, 'max_depth': 8, 'max_features': 'sqrt', 'n_estimators': 300}
# accuracy :  0.9124234986090658

# %%
gboost_model = GradientBoostingClassifier(
    random_state=123,
    learning_rate=0.1,
    max_depth=8,
    max_features= 'sqrt',
    n_estimators=300
)
gboost_model.fit(train_pca_diaz_df, new_y_train)
joblib.dump(gboost_model, "/content/drive/MyDrive/model/gboost_model.joblib")
# Out:
# ['/content/drive/MyDrive/model/gboost_model.joblib']

# %%
plot_feature_importances(gboost_model.feature_importances_, train_pca_diaz_df.columns)
# Out:
#                             coef_value
# pc1_1                         0.294243
# pc1_2                         0.099762
# pc2_1                         0.074492
# pc2_2                         0.074276
# Tuition_fees_up_to_date       0.059123
# Course                        0.051743
# Fathers_occupation            0.039182
# Mothers_occupation            0.038146
# Application_mode              0.036196
# Scholarship_holder            0.032462
# Mothers_qualification         0.028703
# Inflation_rate                0.028352
# Fathers_qualification         0.026867
# Unemployment_rate             0.025150
# Debtor                        0.016509
# Application_order             0.016059
# Previous_qualification        0.014181
# Gender                        0.012554
# Displaced                     0.010964
# Marital_status                0.006946
# Daytime_evening_attendance    0.005370
# Nacionality                   0.004856
# International                 0.002548
# ...

# %%
y_pred_train = gboost_model.predict(train_pca_diaz_df)
y_pred_train = encoder.inverse_transform(y_pred_train)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_train, y_true=y_train)
print(classification_report(y_pred=y_pred_train, y_true=y_train))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       1.00      1.00      1.00      2101
#     Enrolled       1.00      1.00      1.00      2101
#     Graduate       1.00      1.00      1.00      2101
#
#     accuracy                           1.00      6303
#    macro avg       1.00      1.00      1.00      6303
# weighted avg       1.00      1.00      1.00      6303

# %%
y_pred_test = gboost_model.predict(test_pca_diaz_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_test, y_true=y_test)
print(classification_report(y_pred=y_pred_test, y_true=y_test))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.63      0.82      0.72        72
#     Enrolled       0.20      0.05      0.08        42
#     Graduate       0.72      0.80      0.76       108
#
#     accuracy                           0.66       222
#    macro avg       0.52      0.55      0.52       222
# weighted avg       0.60      0.66      0.62       222

# %% [markdown]
# ## XGBClassifier

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier()

param_grid = {
    'max_depth': [5, 8],
    'n_estimators': [200, 300],
    'learning_rate': [0.01, 0.1]
}

CV_xgb = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5, n_jobs=-1)
CV_xgb.fit(train_pca_diaz_df, new_y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None,...one,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
# ...

# %%
print("best parameters: ", CV_xgb.best_params_)
print("accuracy : ", CV_xgb.best_score_)
# Out:
# best parameters:  {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 300}
# accuracy :  0.9033783970897373

# %%
xgb_model = XGBClassifier(
    learning_rate=0.1, max_depth=8, n_estimators=300
)
xgb_model.fit(train_pca_diaz_df, new_y_train)
joblib.dump(gboost_model, "/content/drive/MyDrive/model/xgb_model.joblib")
# Out:
# ['/content/drive/MyDrive/model/xgb_model.joblib']

# %%
plot_feature_importances(xgb_model.feature_importances_, train_pca_diaz_df.columns)
# Out:
#                             coef_value
# Tuition_fees_up_to_date       0.185843
# Scholarship_holder            0.091453
# pc1_1                         0.089906
# Debtor                        0.054382
# Nacionality                   0.040345
# pc1_2                         0.037822
# Previous_qualification        0.037699
# Mothers_occupation            0.034788
# Daytime_evening_attendance    0.033257
# Course                        0.033205
# Gender                        0.031571
# pc2_1                         0.030570
# Educational_special_needs     0.030104
# Inflation_rate                0.029703
# Application_mode              0.029702
# Marital_status                0.028668
# Mothers_qualification         0.028337
# Unemployment_rate             0.028261
# Application_order             0.027238
# pc2_2                         0.026652
# Fathers_qualification         0.026368
# Fathers_occupation            0.025635
# Displaced                     0.018490
# ...

# %%
y_pred_train = xgb_model.predict(train_pca_diaz_df)
y_pred_train = encoder.inverse_transform(y_pred_train)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_train, y_true=y_train)
print(classification_report(y_pred=y_pred_train, y_true=y_train))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       1.00      1.00      1.00      2101
#     Enrolled       1.00      1.00      1.00      2101
#     Graduate       1.00      1.00      1.00      2101
#
#     accuracy                           1.00      6303
#    macro avg       1.00      1.00      1.00      6303
# weighted avg       1.00      1.00      1.00      6303

# %%
y_pred_test = xgb_model.predict(test_pca_diaz_df)
y_pred_test = encoder.inverse_transform(y_pred_test)

confusion_matrix_diaz_df = evaluating(y_pred=y_pred_test, y_true=y_test)
print(classification_report(y_pred=y_pred_test, y_true=y_test))

sns.heatmap(confusion_matrix_diaz_df, annot=True, annot_kws={'size': 14}, fmt='d', cmap='YlGnBu')
plt.ylabel('True label', fontsize=15)
plt.xlabel('Predicted label', fontsize=15)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#      Dropout       0.56      0.79      0.66        72
#     Enrolled       0.07      0.02      0.04        42
#     Graduate       0.73      0.72      0.73       108
#
#     accuracy                           0.61       222
#    macro avg       0.45      0.51      0.47       222
# weighted avg       0.55      0.61      0.57       222

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Pada proses analisis data pada proyek ini, ada berbagai pertimbangan faktor yang dapat mempengaruhi klasifikasi pada siswa, antara lain :
# 1. Curricular_units_1st_sem_enrolled : Jumlah mata kuliah yang diambil siswa pada semester 1
# 2. Curricular_units_1st_sem_evaluations : Jumlah mata kuliah yang dievaulasi pada semester 1
# 3. Curricular_units_1st_sem_approved : Jumlah mata kuliah yang disetujui atau diakui pada semester 1
# 4. Curricular_units_1st_sem_grade : Hasil akademik untuk setiap mata kuliah yang diambil oleh siswa pada semester 1
# 5. Curricular_units_2nd_sem_enrolled : Jumlah mata kuliah yang diambil siswa pada semester 2
# 6. Curricular_units_2nd_sem_evaluations : Jumlah mata kuliah yang dievaulasi pada semester 2
# 7. Curricular_units_2nd_sem_approved : Jumlah mata kuliah yang disetujui atau diakui pada semester 2
# 8. Curricular_units_2nd_sem_grade : Hasil akademik untuk setiap mata kuliah yang diambil oleh siswa pada semester 2
# 9. Admission_grade : Nilai atau penilaian yang digunakan sebagai kriteria untuk diterima ke dalam sebuah program pendidikan
# 10. GDP : ukuran nilai pasar total dari semua barang dan jasa yang dihasilkan oleh sebuah negara dalam jangka waktu tertentu, biasanya dalam setahun
# 11. Age_at_enrollment : Usia ketika mendaftarkan diri
# 12. Previous_qualification_grade : Hasil akademik sebelum mendaftar
#
# Melalui faktor tersebut, penulis menjalankan berbagai model machine learning dengan hasil accuracy sebagai berikut:
# - GridSearch : 65%
# - RandomForest : 76%
# - GBoost : 91%
# - XGBClassifier : 90%
#
# Sehingga didapatkan bahwa model GBoost merupakan model terbaik untuk menjalankan proses klasifikasi pada proyek ini, dimana machine learning dengan model GBoost ini lebih banyak memakai faktor akademik sebagai sampel klasifikasinya.

# %%
plot_feature_importances(gboost_model.feature_importances_, train_pca_diaz_df.columns)
# Out:
#                             coef_value
# pc1_1                         0.294243
# pc1_2                         0.099762
# pc2_1                         0.074492
# pc2_2                         0.074276
# Tuition_fees_up_to_date       0.059123
# Course                        0.051743
# Fathers_occupation            0.039182
# Mothers_occupation            0.038146
# Application_mode              0.036196
# Scholarship_holder            0.032462
# Mothers_qualification         0.028703
# Inflation_rate                0.028352
# Fathers_qualification         0.026867
# Unemployment_rate             0.025150
# Debtor                        0.016509
# Application_order             0.016059
# Previous_qualification        0.014181
# Gender                        0.012554
# Displaced                     0.010964
# Marital_status                0.006946
# Daytime_evening_attendance    0.005370
# Nacionality                   0.004856
# International                 0.002548
# ...

# %%
new_cleaned_diaz_df.to_csv("new_cleaned_diaz_df.csv", index=False)
